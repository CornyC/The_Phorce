# %% [markdown]
# ## Import modules

# %%
from System.paths import *
from OMM_interface.openmm import *
import os, re
import numpy as np
from pathlib import Path
from ASE_interface.ase_calculation import CP2K
from Coord_Toolz.mdanalysis import MDA_reader
from Direct_cp2k_calculation.direct_cp2k import Direct_Calculator
from System.paths import Paths
from System.system import *
from ASE_interface.ase_calculation import ASE_system
from Parametrization.parametrization import Parametrization
from Parametrization.optimizers import Optimizer
from Coord_Toolz.mdanalysis import *
from OMM_interface.openmm import OpenMM_system

# %% [markdown]
# ## Configure Paths

# %% [raw]
# system_name = 'mp0mp0'

# %% [raw]
# system_name = 'mp1'

# %% [raw]
# system_name = 'mp1mp1'

# %% [raw]
# system_name = 'mp1mam'

# %% [raw]
# system_name = 'mp2'

# %% [raw]
# system_name = 'mp2mam'

# %% [raw]
# system_name = 'mp2mp2'

# %% [raw]
# system_name = 'ep1'

# %% [raw]
# system_name = 'ep1mam'

# %%
system_name = 'ep2'

# %%
paths = Paths()

paths.working_dir = '/home/ac127777/Documents/TheForceOutput/'+system_name
paths.project_name = system_name

paths.mm_top_file = 'smallbox.psf'
paths.mm_top_file_path = '/home/ac127777/Documents/phosphate_parametrization/cp2k_geom_opts/'+system_name
paths.mm_crd_file = 'structure_0.pdb'
paths.mm_crd_file_path = paths.mm_top_file_path
paths.mm_str_file = 'ep2'+'.str'
paths.mm_str_file_path = '/home/ac127777/Documents/phosphate_parametrization/cp2k_geom_opts/'+system_name
paths.mm_traj_file = 'smallbox.dcd'
paths.mm_traj_file_path = '/home/ac127777/Documents/phosphate_parametrization/cp2k_geom_opts/'+system_name

paths.set()
# Out:
# Created folder /home/ac127777/Documents/TheForceOutput/ep2

# %% [markdown]
# ## Import Molecules:

# %% [markdown]
# Set up System.system.Molecular_system

# %%
Molsys = Molecular_system('net_properties', 'forces')

# %%
Molsys.paths = paths

# %% [markdown]
# Set up Coord_Toolz.mdanalysis.MDA_reader object for both molecules dissolved, one molecule dissolved, and the other molecule dissolved

# %%
MDR = MDA_reader()
MDR.set_traj_input(paths.mm_crd, paths.mm_traj)
# Out:
# ...
# /home/ac127777/anaconda3/envs/mdanalysis-dev/lib/python3.8/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"

# %% [raw]
# MDR.universes['mol1'] = MDR.delete_one_molecule('not resid 2') #mp0mp0
# MDR.universes['mol2'] = MDR.delete_one_molecule('not resid 1')

# %% [raw]
# MDR.universes['mol1'] = MDR.delete_one_molecule('not resid 2 and not resname CLA') #mp0mam
# MDR.universes['mol2'] = MDR.delete_one_molecule('not resid 1')

# %% [raw]
# MDR.universes['nosol'] = MDR.delete_one_molecule('not resname TIP3') #mp1

# %% [raw]
# MDR.universes['mol1'] = MDR.delete_one_molecule('not resid 2 and not resid 4') #mp1mp1
# MDR.universes['mol2'] = MDR.delete_one_molecule('not resid 1 and not resid 3')

# %% [raw]
# MDR.universes['mol1'] = MDR.delete_one_molecule('not resid 2') #mp1mam
# MDR.universes['mol2'] = MDR.delete_one_molecule('not resid 1')

# %% [raw]
# MDR.universes['mol1'] = MDR.delete_one_molecule('not resname SOD') #mp2
# MDR.universes['mol2'] = MDR.delete_one_molecule('not resname MP_2')

# %% [raw]
# MDR.universes['mol1'] = MDR.delete_one_molecule('not resid 2 and not resid 3') #mp2mam
# MDR.universes['mol2'] = MDR.delete_one_molecule('not resid 1')

# %% [raw]
# MDR.universes['mol1'] = MDR.delete_one_molecule('not resid 2 and not resid 123 and not resid 124') #mp2mp2
# MDR.universes['mol2'] = MDR.delete_one_molecule('not resid 1 and not resid 121 and not resid 122')

# %% [raw]
# MDR.universes['mol1'] = MDR.delete_one_molecule('not resname SOD') #ep1
# MDR.universes['mol2'] = MDR.delete_one_molecule('not resname EP1')

# %% [raw]
# MDR.universes['mol1'] = MDR.delete_one_molecule('not resname MAM') #ep1mam
# MDR.universes['mol2'] = MDR.delete_one_molecule('not resname EP1')

# %%
MDR.universes['mol1'] = MDR.delete_one_molecule('not resname SOD') #ep2
MDR.universes['mol2'] = MDR.delete_one_molecule('not resname EP2')

# %% [markdown]
# export nosol

# %% [raw]
# write_single_pdb(MDR.universes['nosol'], 'nosol.pdb', paths.working_dir)

# %% [markdown]
# export mol1 and mol2

# %%
write_single_pdb(MDR.universes['mol1'], 'mol1.pdb', paths.working_dir)
write_single_pdb(MDR.universes['mol2'], 'mol2.pdb', paths.working_dir)
# Out:
# /home/ac127777/anaconda3/envs/mdanalysis-dev/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"

# %% [markdown]
# ...externally generate topology files for mol1 and mol2....
# e.g. run 'charmm -i genpsf.inp -o genpsf.out'

# %% [markdown]
# add paths to coordinate and topology files

# %%
paths.working_dir
# Out:
# '/home/ac127777/Documents/TheForceOutput/ep2/'

# %% [raw]
# paths.mm_nosol_crd_file_path = paths.working_dir
# paths.mm_nosol_crd_file = 'nosol.pdb'
#
# paths.mm_nosol_top_file_path = paths.working_dir
# paths.mm_nosol_top_file = 'nosol.psf'
#
# paths.set()

# %% [raw]
# paths.mm_nosol_crd_file_path

# %%
paths.mm_mol1_crd_file_path = paths.working_dir
paths.mm_mol1_crd_file = 'mol1.pdb'

paths.mm_mol1_top_file_path = paths.working_dir
paths.mm_mol1_top_file = 'mol1.psf'

paths.mm_mol2_crd_file_path = paths.working_dir
paths.mm_mol2_crd_file = 'mol2.pdb'

paths.mm_mol2_top_file_path = paths.working_dir
paths.mm_mol2_top_file = 'mol2.psf'

paths.set()

# %% [markdown]
# check if they work

# %%
for filepath in [paths.mm_mol1_crd, paths.mm_mol1_top, paths.mm_mol2_crd, paths.mm_mol2_top]:
    check_if_file_exists(filepath)

# %% [raw]
# for filepath in [paths.mm_nosol_crd, paths.mm_nosol_top]:
#     check_if_file_exists(filepath)

# %% [markdown]
# Fill Molecular_system storage

# %%
Molsys.set_ini_coords(MDR)

# %% [markdown]
# ## Run QM scheme

# %% [markdown]
# ### option 1.1: no charge calc, no optimization

# %% [markdown]
# define cp2k_inp

# %% [raw]
# cp2k_inp1 = """
# &FORCE_EVAL
#   METHOD Quickstep              ! Electronic structure method (DFT,...)
#   &DFT
#     BASIS_SET_FILE_NAME  BASIS_MOLOPT_UZH
#     POTENTIAL_FILE_NAME  POTENTIAL_UZH
#     CHARGE 0
#     &MGRID
#       NGRIDS 5
#       CUTOFF 550
#       REL_CUTOFF 80
#     &END MGRID
#     &QS
#       METHOD GPW
#       EPS_DEFAULT 1.0E-12
#     &END QS
#     &POISSON                    ! Solver requested for non periodic calculations
#       PERIODIC XYZ
#       PSOLVER  PERIODIC          ! Type of solver
#     &END POISSON
#     &SCF                        ! Parameters controlling the convergence of the scf. This section should not be changed.
#       SCF_GUESS ATOMIC
#       EPS_SCF 1.0E-5
#       MAX_SCF 800
#       &MIXING
#         ALPHA 0.4
#       &END MIXING
#       &OT
#         MINIMIZER CG
#       &END OT
#     &END SCF
#     &XC                        ! Parameters needed to compute the electronic exchange potential
#       &VDW_POTENTIAL
#         DISPERSION_FUNCTIONAL PAIR_POTENTIAL
#         &PAIR_POTENTIAL
#           TYPE DFTD3
#           PARAMETER_FILE_NAME  dftd3.dat
#           REFERENCE_FUNCTIONAL PBE
#           CALCULATE_C9_TERM TRUE
#           REFERENCE_C9_TERM TRUE
#         &END PAIR_POTENTIAL
#       &END VDW_POTENTIAL
#       &XC_FUNCTIONAL PBE
#       &END XC_FUNCTIONAL
#     &END XC
#   &END DFT
#
#   &SUBSYS
#     &KIND H
#       ELEMENT H
#       BASIS_SET TZV2P-MOLOPT-PBE-GTH-q1
#       POTENTIAL GTH-PBE-q1
#     &END KIND
#     &KIND C
#       ELEMENT C
#       BASIS_SET TZV2P-MOLOPT-PBE-GTH-q4
#       POTENTIAL GTH-PBE-q4
#     &END KIND
#     &KIND P
#       ELEMENT P
#       BASIS_SET TZV2P-MOLOPT-PBE-GTH-q5
#       POTENTIAL GTH-PBE-q5
#     &END KIND
#     &KIND O
#       ELEMENT O
#       BASIS_SET TZV2P-MOLOPT-PBE-GTH-q6
#       POTENTIAL GTH-PBE-q6
#     &END KIND
#     &KIND N
#       ELEMENT N
#       BASIS_SET TZV2P-MOLOPT-PBE-GTH-q5
#       POTENTIAL GTH-PBE-q5
#     &END KIND
#     &KIND CL
#       ELEMENT Cl
#       BASIS_SET TZV2P-MOLOPT-PBE-GTH-q7
#       POTENTIAL GTH-PBE-q7
#     &END KIND
#     &KIND NA
#       ELEMENT Na
#       BASIS_SET TZV2P-MOLOPT-PBE-GTH-q9
#       POTENTIAL GTH-PBE-q9
#     &END KIND
#     &PRINT
#       &ATOMIC_COORDINATES LOW
#       &END ATOMIC_COORDINATES
#       &INTERATOMIC_DISTANCES LOW
#       &END INTERATOMIC_DISTANCES
#       &KINDS
#         POTENTIAL
#       &END KINDS
#       &TOPOLOGY_INFO
#         PSF_INFO
#       &END TOPOLOGY_INFO
#     &END PRINT
#   &END SUBSYS
#
#   &PRINT
#     &FORCES ON
#     &END FORCES
#   &END PRINT
#
# &END FORCE_EVAL """

# %% [markdown]
# Run the DFT calculation

# %% [raw]
# Molsys.collect_ase_settings(n_threads=6, cell_dimensions=([16.0, 16.0, 16.0]), pbc=([True, True, True]), input_control=cp2k_inp1, run_type='single_point')
# for system_name in Molsys.ini_coords.keys():
#     if isinstance(Molsys.ini_coords[system_name], np.ndarray):
#         Molsys.generate_qm_data_w_ase(sys_type=system_name, paths=paths, atomgroup=MDR.universes[system_name], atomgroup_name=system_name)

# %% [markdown]
# ### option 1.2: no charge calc, geometry optimization

# %% [markdown]
# define cp2k_inp

# %% [raw]
# # same as previous

# %% [markdown]
# Run the DFT calculation

# %% [raw]
# Molsys.collect_ase_settings(n_threads=6, cell_dimensions=([16.0, 16.0, 16.0]), pbc=([True,True,True]), input_control=cp2k_inp1, run_type='optimization')
# Molsys.generate_qm_data_w_ase(sys_type='all', paths=paths, atomgroup=MDR.universes['all'], atomgroup_name='all')

# %% [markdown]
# use the new optimized coords and run a single-point calculation:

# %% [markdown]
# generate a new MDA_reader object

# %% [raw]
# MDR_optcoords = MDA_reader()

# %% [markdown]
# exchange the ini_coords for the opt_coords

# %% [raw]
# MDR_optcoords.universes['all'] = merge_atoms_positions(Molsys.opt_coords['all'], MDR.universes['all'].atoms)

# %% [raw]
# MDR_optcoords.universes['mol1'] = MDR_optcoords.delete_one_molecule('not resid 2')
# MDR_optcoords.universes['mol2'] = MDR_optcoords.delete_one_molecule('not resid 1')

# %% [markdown]
# Run the DFT calculation

# %% [raw]
# for system_name in ['mol1', 'mol2']:
#     Molsys.generate_qm_data_w_ase(sys_type=system_name, paths=paths, atomgroup=MDR_optcoords.universes[system_name], atomgroup_name=system_name)

# %% [markdown]
# ### option 2.1: calculate charges, energies, forces, no geom opt

# %% [markdown]
# define cp2k_inp

# %%
cp2k_inp2 = """  
&FORCE_EVAL
  METHOD Quickstep              ! Electronic structure method (DFT,...)
  &DFT
    BASIS_SET_FILE_NAME  BASIS_MOLOPT_UZH
    POTENTIAL_FILE_NAME  POTENTIAL_UZH
    CHARGE 0
    &MGRID
      NGRIDS 5
      CUTOFF 550
      REL_CUTOFF 80
    &END MGRID
    &QS
      METHOD GPW
      EPS_DEFAULT 1.0E-12
    &END QS
    &POISSON                    ! Solver requested for non periodic calculations
      PERIODIC XYZ
      PSOLVER  PERIODIC          ! Type of solver
    &END POISSON
    &SCF                        ! Parameters controlling the convergence of the scf. This section should not be changed. 
      SCF_GUESS ATOMIC
      EPS_SCF 1.0E-5
      MAX_SCF 800
      &MIXING
        ALPHA 0.4
      &END MIXING
      &OT
        MINIMIZER CG
      &END OT
    &END SCF
    &XC                        ! Parameters needed to compute the electronic exchange potential 
      &VDW_POTENTIAL
        DISPERSION_FUNCTIONAL PAIR_POTENTIAL
        &PAIR_POTENTIAL
          TYPE DFTD3
          PARAMETER_FILE_NAME  dftd3.dat
          REFERENCE_FUNCTIONAL PBE
          CALCULATE_C9_TERM TRUE
          REFERENCE_C9_TERM TRUE
        &END PAIR_POTENTIAL
      &END VDW_POTENTIAL
      &XC_FUNCTIONAL PBE
      &END XC_FUNCTIONAL
    &END XC
  &END DFT

  &SUBSYS
    &KIND H
      ELEMENT H
      BASIS_SET TZV2P-MOLOPT-PBE-GTH-q1
      POTENTIAL GTH-PBE-q1
    &END KIND
    &KIND C
      ELEMENT C
      BASIS_SET TZV2P-MOLOPT-PBE-GTH-q4
      POTENTIAL GTH-PBE-q4
    &END KIND
    &KIND P
      ELEMENT P
      BASIS_SET TZV2P-MOLOPT-PBE-GTH-q5
      POTENTIAL GTH-PBE-q5
    &END KIND
    &KIND O
      ELEMENT O
      BASIS_SET TZV2P-MOLOPT-PBE-GTH-q6
      POTENTIAL GTH-PBE-q6
    &END KIND
    &KIND NA
      ELEMENT Na
      BASIS_SET TZV2P-MOLOPT-PBE-GTH-q9
      POTENTIAL GTH-PBE-q9
    &END KIND
    &KIND N
      ELEMENT N
      BASIS_SET TZV2P-MOLOPT-PBE-GTH-q5
      POTENTIAL GTH-PBE-q5
    &END KIND
    &PRINT
      &ATOMIC_COORDINATES LOW
      &END ATOMIC_COORDINATES
      &INTERATOMIC_DISTANCES LOW
      &END INTERATOMIC_DISTANCES
      &KINDS 
        POTENTIAL
      &END KINDS
      &TOPOLOGY_INFO
        PSF_INFO
      &END TOPOLOGY_INFO
    &END PRINT
  &END SUBSYS

  &PROPERTIES
    &RESP
      &SPHERE_SAMPLING
            AUTO_VDW_RADII_TABLE CAMBRIDGE
            AUTO_RMIN_SCALE 1.0
            AUTO_RMAX_SCALE 3.0
      &END
      &PRINT
        &COORD_FIT_POINTS
        &END
        &V_RESP_CUBE
        &END
      &END
    &END RESP
  &END PROPERTIES

  &PRINT
    &FORCES ON
    &END FORCES
  &END PRINT

&END FORCE_EVAL """

# %% [markdown]
# Run the DFT calculation

# %% [raw]
# Molsys.collect_cp2k_settings(cp2k_input=cp2k_inp2, n_threads=6, cp2k_binary_name='cp2k.ssmp', cp2k_run_type='single_point')
# Molsys.generate_qm_data_w_cp2k(sys_type='nosol', paths=paths, MDA_reader=MDR.universes['nosol'], charge_type='Mulliken')

# %% [raw]
# for system_name in Molsys.ini_coords.keys():
#     if isinstance(Molsys.ini_coords[system_name], np.ndarray):
#         Molsys.generate_qm_data_w_cp2k(sys_type=system_name, paths=paths, MDA_reader=MDR.universes[system_name], charge_type='Mulliken')

# %% [markdown]
# ### option 2.2: calculate charges, energies, forces, and optimize geometry

# %% [markdown]
# define cp2k_inp

# %% [raw]
# cp2k_inp2_2 = """
# &GLOBAL
#   PROJECT mp0_opt
#   RUN_TYPE GEO_OPT
#   PRINT_LEVEL MEDIUM
# &END GLOBAL
#
# &FORCE_EVAL
#   METHOD Quickstep              ! Electronic structure method (DFT,...)
#   &DFT
#     BASIS_SET_FILE_NAME  ../BASIS_MOLOPT_UZH
#     POTENTIAL_FILE_NAME  ../POTENTIAL_UZH
#     CHARGE 0
#     &MGRID
#       NGRIDS 5
#       CUTOFF 550
#       REL_CUTOFF 80
#     &END MGRID
#     &QS
#       METHOD GPW
#       EPS_DEFAULT 1.0E-12
#     &END QS
#     &POISSON                    ! Solver requested for non periodic calculations
#       PERIODIC XYZ
#       PSOLVER  PERIODIC          ! Type of solver
#     &END POISSON
#     &SCF                        ! Parameters controlling the convergence of the scf. This section should not be changed.
#       SCF_GUESS ATOMIC
#       EPS_SCF 1.0E-5
#       MAX_SCF 300
#       &MIXING
#         ALPHA 0.4
#       &END MIXING
#       &OT
#         MINIMIZER CG
#       &END OT
#       &PRINT
#         &RESTART LOW
#           ADD_LAST NUMERIC
#           FILENAME SCF_RESTART
#         &END RESTART
#       &END PRINT
#     &END SCF
#     &XC                        ! Parameters needed to compute the electronic exchange potential
#       &VDW_POTENTIAL
#         DISPERSION_FUNCTIONAL PAIR_POTENTIAL
#         &PAIR_POTENTIAL
#           TYPE DFTD3
#           PARAMETER_FILE_NAME  ../dftd3.dat
#           REFERENCE_FUNCTIONAL PBE
#           CALCULATE_C9_TERM TRUE
#           REFERENCE_C9_TERM TRUE
#         &END PAIR_POTENTIAL
#       &END VDW_POTENTIAL
#       &XC_FUNCTIONAL PBE
#       &END XC_FUNCTIONAL
#     &END XC
#   &END DFT
#
#   &SUBSYS
#     &CELL
#       SYMMETRY CUBIC
#       ABC 16.0 16.0 16.0
#       ALPHA_BETA_GAMMA  90.0 90.0 90.0
#       PERIODIC XYZ
#     &END CELL
#     &TOPOLOGY                    ! Section used to center the atomic coordinates in the given box. Useful for big molecules
#       &CENTER_COORDINATES
#       &END
#       COORD_FILE_FORMAT pdb
#       COORD_FILE_NAME  smallbox.pdb
#       CONN_FILE_FORMAT upsf
#       CONN_FILE_NAME  ../smallbox.psf
#     &END
#     &KIND H
#       ELEMENT H
#       BASIS_SET TZV2P-MOLOPT-PBE-GTH-q1
#       POTENTIAL GTH-PBE-q1
#     &END KIND
#     &KIND C
#       ELEMENT C
#       BASIS_SET TZV2P-MOLOPT-PBE-GTH-q4
#       POTENTIAL GTH-PBE-q4
#     &END KIND
#     &KIND P
#       ELEMENT P
#       BASIS_SET TZV2P-MOLOPT-PBE-GTH-q5
#       POTENTIAL GTH-PBE-q5
#     &END KIND
#     &KIND O
#       ELEMENT O
#       BASIS_SET TZV2P-MOLOPT-PBE-GTH-q6
#       POTENTIAL GTH-PBE-q6
#     &END KIND
#     &PRINT
#       &ATOMIC_COORDINATES LOW
#       &END ATOMIC_COORDINATES
#       &INTERATOMIC_DISTANCES LOW
#       &END INTERATOMIC_DISTANCES
#       &KINDS
#         POTENTIAL
#       &END KINDS
#       &TOPOLOGY_INFO
#         PSF_INFO
#       &END TOPOLOGY_INFO
#     &END PRINT
#   &END SUBSYS
#
#   &PROPERTIES
#     &RESP
#       &SPHERE_SAMPLING
#             AUTO_VDW_RADII_TABLE CAMBRIDGE
#             AUTO_RMIN_SCALE 1.0
#             AUTO_RMAX_SCALE 3.0
#       &END
#       &PRINT
#         &COORD_FIT_POINTS
#         &END
#         &V_RESP_CUBE
#         &END
#       &END
#     &END RESP
#   &END PROPERTIES
#
#   &PRINT
#     &FORCES ON
#     &END FORCES
#   &END PRINT
#
# &END FORCE_EVAL
#
# &MOTION
#   &GEO_OPT
#     OPTIMIZER LBFGS
#     MAX_DR    3.0E-03
#     MAX_FORCE 4.5E-04
#     RMS_DR    1.5E-03
#     RMS_FORCE 3.0E-04
#   &END
#   &CONSTRAINT
#     &FIXED_ATOMS
#       COMPONENTS_TO_FIX XYZ
#       LIST 12..347
#     &END
#   &END CONSTRAINT
#   &PRINT
#     &FORCES
#       UNIT N
#       FORMAT  XYZ
#       FILENAME  geom_opt_forces
#     &END FORCES
#     &RESTART LOW
#       ADD_LAST NUMERIC
#       FILENAME MOTION_RESTART
#     &END RESTART
#   &END PRINT
# &END MOTION
# """

# %% [markdown]
# Run DFT calc

# %% [raw]
# Molsys.collect_cp2k_settings(cp2k_input=cp2k_inp2_2, n_threads=6, cp2k_binary_name='cp2k.ssmp', cp2k_run_type='optimization')
# Molsys.generate_qm_data_w_cp2k(sys_type='all', paths=paths, MDA_reader=MDR, charge_type='RESP')

# %% [markdown]
# use the new optimized coords and run a single-point calculation:

# %% [markdown]
# generate a new MDA_reader object

# %% [raw]
# MDR_optcoords = MDA_reader()

# %% [markdown]
# exchange the ini_coords for the opt_coords

# %% [raw]
# MDR_optcoords.universes['all'] = merge_atoms_positions(Molsys.opt_coords['all'], MDR.universes['all'].atoms)

# %% [raw]
# MDR_optcoords.universes['mol1'] = MDR_optcoords.delete_one_molecule('not resid 2')
# MDR_optcoords.universes['mol2'] = MDR_optcoords.delete_one_molecule('not resid 1')

# %% [markdown]
# Run the DFT calculation

# %% [raw]
# for system_name in ['mol1', 'mol2']:
#     Molsys.generate_qm_data_w_cp2k(sys_type=system_name, paths=paths, MDA_reader=MDR_optcoords.universes[system_name])

# %% [markdown]
# ### option 3.1: read in data from external cluster calcs

# %% [raw]
# Molsys.read_qm_charges_energies_forces_optcoords(sys_type='all', path=paths.mm_top_file_path, cp2k_outfilename='mp1mam_opt', filename='geom_opt', charge_type='RESP')

# %% [markdown]
# use the new optimized coords and run a single-point calculation:

# %% [markdown]
# generate a new MDA_reader object

# %% [raw]
# MDR_optcoords = MDA_reader()

# %% [markdown]
# exchange the ini_coords for the opt_coords

# %% [raw]
# MDR_optcoords.universes['all'] = merge_atoms_positions(Molsys.opt_coords['all'], MDR.universes['all'].atoms)

# %% [raw]
# MDR_optcoords.universes['mol1'] = MDR_optcoords.delete_one_molecule('not resid 2 and not resname CLA')
# MDR_optcoords.universes['mol2'] = MDR_optcoords.delete_one_molecule('not resid 1')

# %% [markdown]
# Run the DFT calculation

# %% [raw]
# Molsys.collect_ase_settings(n_threads=6, cell_dimensions=([16.0, 16.0, 16.0]), pbc=([True, True, True]), input_control=cp2k_inp1, run_type='single_point')
# for system_name in ['mol1', 'mol2']:
#     Molsys.generate_qm_data_w_ase(sys_type=system_name, paths=paths, atomgroup=MDR_optcoords.universes[system_name], atomgroup_name=system_name)

# %% [markdown]
# ### option 3.2: read in all data from external cluster calcs

# %% [markdown]
# entire system

# %% [raw]
# Molsys.read_qm_charges_energies_forces_optcoords(sys_type='all', paths=paths.mm_top_file_path, cp2k_outfilename='geom_opt', filename='mp0mp0'+'_opt', charge_type='RESP') #mp0mp0

# %% [raw]
# Molsys.read_qm_charges_energies_forces_optcoords('all', paths.mm_top_file_path, 'geom_opt', 'mp0mam'+'_opt', 'RESP') #mp0mam

# %% [raw]
# Molsys.read_qm_charges_energies_forces_optcoords('all', paths.mm_top_file_path, 'geom_opt', 'mp1'+'_opt', 'RESP') #mp1

# %% [raw]
# Molsys.read_qm_charges_energies_forces_optcoords('all', paths.mm_top_file_path, 'geom_opt', 'mp1mam'+'_opt', 'RESP') #mp1mp1 (fkd up filenames lol)

# %% [raw]
# Molsys.read_qm_charges_energies_forces_optcoords('all', paths.mm_top_file_path, 'geom_opt', 'mp1mam'+'_opt', 'RESP') #mp1mam

# %% [raw]
# Molsys.read_qm_charges_energies_forces_optcoords('all', paths.mm_top_file_path, 'geom_opt', 'mp2'+'_opt', 'RESP') #mp2

# %% [raw]
# Molsys.read_qm_charges_energies_forces_optcoords('all', paths.mm_top_file_path, 'geom_opt', 'mp2mam'+'_opt', 'RESP') #mp2mam

# %% [raw]
# Molsys.read_qm_charges_energies_forces_optcoords('all', paths.mm_top_file_path, 'geom_opt', 'mp2mp2'+'_opt', 'RESP') #mp2mp2

# %% [raw]
# Molsys.read_qm_charges_energies_forces_optcoords('all', paths.mm_top_file_path, 'geom_opt', 'ep1'+'_opt', 'RESP') #ep1

# %% [raw]
# Molsys.read_qm_charges_energies_forces_optcoords('all', paths.mm_top_file_path, 'geom_opt', 'ep1mam'+'_opt', 'RESP') #ep1mam

# %%
Molsys.read_qm_charges_energies_forces_optcoords('all', paths.mm_top_file_path, 'geom_opt', 'ep2'+'_opt', 'RESP') #ep2
# Out:
# reading qm frame 0 info
# /home/ac127777/anaconda3/envs/mdanalysis-dev/lib/python3.8/site-packages/MDAnalysis/analysis/base.py:438: UserWarning: Reader has no dt information, set to 1.0 ps
#   self.times[i] = ts.time
# reading qm frame 1 info
# reading qm frame 2 info
# reading qm frame 3 info
# reading qm frame 4 info
# reading qm frame 5 info
# reading qm frame 6 info
# reading qm frame 7 info
# reading qm frame 8 info
# reading qm frame 9 info
# reading qm frame 10 info
# reading qm frame 11 info
# reading qm frame 12 info
# reading qm frame 13 info
# reading qm frame 14 info
# reading qm frame 15 info
# reading qm frame 16 info
# reading qm frame 17 info
# reading qm frame 18 info
# reading qm frame 19 info
# reading qm frame 20 info
# reading qm frame 21 info
# reading qm frame 22 info
# reading qm frame 23 info
# reading qm frame 24 info
# reading qm frame 25 info
# reading qm frame 26 info
# reading qm frame 27 info
# reading qm frame 28 info
# reading qm frame 29 info
# ...

# %% [markdown]
# net forces: nosol or mol1&mol2

# %% [raw]
# for system_type in ['mol1', 'mol2']:
#     print(system_type)
#     Molsys.read_ase_energy_forces(system_type, paths.mm_stream[:-8]+'_sp', system_type) #mp0mp0

# %% [raw]
# for system_type in ['mol1', 'mol2']:
#     print(system_type)
#     Molsys.read_qm_charges_energies_forces_optcoords(system_type, paths.mm_stream[:-8]+'_sp/', system_type+'_sp') #mp0mam

# %% [raw]
# Molsys.read_ase_energy_forces('nosol', paths.mm_nosol_crd_file_path+'/mp1', 'nosol') #mp1

# %% [raw]
# for system_type in ['mol1', 'mol2']:
#     print(system_type)
#     Molsys.read_qm_charges_energies_forces_optcoords(system_type, paths.mm_stream[:-8]+'_sp/', system_type+'_sp') #mp1mp1 & mp1mam

# %% [raw]
# for system_type in ['mol1', 'mol2']:
#     print(system_type)
#     Molsys.read_qm_charges_energies_forces_optcoords(system_type, paths.mm_stream[:-8]+'_sp/', system_type+'_sp', 'cp2k_direct') #mp2

# %% [raw]
# for system_type in ['mol1', 'mol2']:
#     print(system_type)
#     Molsys.read_qm_charges_energies_forces_optcoords(system_type, paths.mm_stream[:-8]+'_sp/', system_type+'_sp', 'cp2k_direct') #mp2mam

# %% [raw]
# for system_type in ['mol1', 'mol2']:
#     print(system_type)
#     Molsys.read_qm_charges_energies_forces_optcoords(system_type, paths.mm_stream[:-8]+'_sp/', system_type+'_sp') #mp2mp2

# %% [raw]
# for system_type in ['mol1', 'mol2']:
#     print(system_type)
#     Molsys.read_qm_charges_energies_forces_optcoords(system_type, paths.mm_stream[:-8]+'_sp/', system_type+'_sp', 'cp2k_direct') #ep1

# %% [raw]
# for system_type in ['mol1', 'mol2']:
#     print(system_type)
#     Molsys.read_qm_charges_energies_forces_optcoords(system_type, paths.mm_stream[:-8]+'_sp/', system_type+'_sp', 'cp2k_direct') #ep1mam

# %%
for system_type in ['mol1', 'mol2']:
    print(system_type)
    Molsys.read_qm_charges_energies_forces_optcoords(system_type, paths.mm_stream[:-8]+'_sp/', system_type+'_sp', 'cp2k_direct') #ep2
# Out:
# mol1
# reading qm frame 0 info
# reading qm frame 1 info
# reading qm frame 2 info
# reading qm frame 3 info
# reading qm frame 4 info
# reading qm frame 5 info
# reading qm frame 6 info
# reading qm frame 7 info
# reading qm frame 8 info
# reading qm frame 9 info
# reading qm frame 10 info
# reading qm frame 11 info
# reading qm frame 12 info
# reading qm frame 13 info
# reading qm frame 14 info
# reading qm frame 15 info
# reading qm frame 16 info
# reading qm frame 17 info
# reading qm frame 18 info
# reading qm frame 19 info
# reading qm frame 20 info
# reading qm frame 21 info
# reading qm frame 22 info
# reading qm frame 23 info
# reading qm frame 24 info
# reading qm frame 25 info
# reading qm frame 26 info
# reading qm frame 27 info
# reading qm frame 28 info
# reading qm frame 29 info
# reading qm frame 30 info
# reading qm frame 31 info
# reading qm frame 32 info
# reading qm frame 33 info
# reading qm frame 34 info
# reading qm frame 35 info
# reading qm frame 36 info
# ...

# %% [markdown]
# generate a new MDA_reader object

# %%
MDR_optcoords = MDA_reader()

# %% [markdown]
# load the opt_coords - 'all' system

# %%
MDR_optcoords.universes['all'] = merge_atoms_positions(Molsys.opt_coords['all'], MDR.universes['all'].atoms)

# %% [markdown]
# load the opt_coords - nosol/mol1/mol2

# %% [raw]
# MDR_optcoords.universes['mol1'] = MDR_optcoords.delete_one_molecule('not resid 2') #mp0mp0
# MDR_optcoords.universes['mol2'] = MDR_optcoords.delete_one_molecule('not resid 1')

# %% [raw]
# MDR_optcoords.universes['mol1'] = MDR_optcoords.delete_one_molecule('not resid 2 and not resname CLA')
# MDR_optcoords.universes['mol2'] = MDR_optcoords.delete_one_molecule('not resid 1') #mp0mam

# %% [raw]
# MDR_optcoords.universes['nosol'] = MDR_optcoords.delete_one_molecule('not resname TIP3') #mp1

# %% [raw]
# MDR_optcoords.universes['mol1'] = MDR.delete_one_molecule('not resid 2 and not resid 4') #mp1mp1
# MDR_optcoords.universes['mol2'] = MDR.delete_one_molecule('not resid 1 and not resid 3')

# %% [raw]
# MDR_optcoords.universes['mol1'] = MDR_optcoords.delete_one_molecule('not resid 2') #mp1mam
# MDR_optcoords.universes['mol2'] = MDR_optcoords.delete_one_molecule('not resid 1')

# %% [raw]
# MDR_optcoords.universes['mol1'] = MDR_optcoords.delete_one_molecule('not resname SOD') #mp2
# MDR_optcoords.universes['mol2'] = MDR_optcoords.delete_one_molecule('not resname MP_2')

# %% [raw]
# MDR_optcoords.universes['mol1'] = MDR_optcoords.delete_one_molecule('not resid 2 and not resid 3') #mp2mam
# MDR_optcoords.universes['mol2'] = MDR_optcoords.delete_one_molecule('not resid 1')

# %% [raw]
# MDR_optcoords.universes['mol1'] = MDR.delete_one_molecule('not resid 2 and not resid 123 and not resid 124') #mp2mp2
# MDR_optcoords.universes['mol2'] = MDR.delete_one_molecule('not resid 1 and not resid 121 and not resid 122')

# %% [raw]
# MDR_optcoords.universes['mol1'] = MDR_optcoords.delete_one_molecule('not resname SOD') #ep1
# MDR_optcoords.universes['mol2'] = MDR_optcoords.delete_one_molecule('not resname EP1')

# %% [raw]
# MDR_optcoords.universes['mol1'] = MDR_optcoords.delete_one_molecule('not resname MAM') #ep1mam
# MDR_optcoords.universes['mol2'] = MDR_optcoords.delete_one_molecule('not resname EP1')

# %%
MDR_optcoords.universes['mol1'] = MDR_optcoords.delete_one_molecule('not resname SOD') #ep2
MDR_optcoords.universes['mol2'] = MDR_optcoords.delete_one_molecule('not resname EP2')

# %% [markdown]
# optional but recommended: Set ini_coords to optcoords

# %%
Molsys.set_ini_coords(MDR_optcoords)

# %% [markdown]
# ### calculate QM net forces

# %%
Molsys.calculate_qm_net_forces()

# %% [markdown]
# ## Run MM scheme

# %% [markdown]
# Set up OpenMM system(s) and link them to Molecular_system

# %% [markdown]
# first do entire system

# %%
omm_sys_all = OpenMM_system(topology_format='CHARMM', top_file=paths.mm_top, crd_format='PDB',
                        crd_file=paths.mm_crd, charmm_param_file=paths.mm_stream, pbc=True,
                        cell=[1.6, 1.6, 1.6], angles=[90, 90, 90])

# %%
omm_sys_all.create_system_params['nonbondedCutoff'] = 0.8 * unit.nanometer
omm_sys_all.create_system_params['constraints'] = app.HBonds
omm_sys_all.import_molecular_system()
# Out:
# /home/ac127777/Documents/TheForce/OMM_interface
# /home/ac127777/Documents/TheForce/OMM_interface/top_all36_cgenff.rtf

# %%
omm_sys_all.set_integrator()

# %%
omm_sys_all.set_platform()
omm_sys_all.create_openmm_system()

# %%
omm_sys_all.set_openmm_context()
# Out:
# Number of constraints: 237
# constraints settings: HBonds
# make sure these are correct before setting context

# %%
Molsys.openmm_systems['all'] = omm_sys_all

# %% [markdown]
# then for molecule 1

# %%
omm_sys_mol1 = OpenMM_system(topology_format='CHARMM', top_file=paths.mm_mol1_top, crd_format='PDB',
                        crd_file=paths.mm_mol1_crd, charmm_param_file=paths.mm_stream, pbc=True,
                        cell=[1.6, 1.6, 1.6], angles=[90, 90, 90])

# %%
omm_sys_mol1.create_system_params['nonbondedCutoff'] = 0.8 * unit.nanometer
omm_sys_mol1.create_system_params['constraints'] = app.HBonds
omm_sys_mol1.import_molecular_system()
omm_sys_mol1.set_integrator()
omm_sys_mol1.set_platform()
omm_sys_mol1.create_openmm_system()
omm_sys_mol1.set_openmm_context()
# Out:
# /home/ac127777/Documents/TheForce/OMM_interface
# /home/ac127777/Documents/TheForce/OMM_interface/top_all36_cgenff.rtf
# Number of constraints: 237
# constraints settings: HBonds
# make sure these are correct before setting context

# %%
Molsys.openmm_systems['mol1'] = omm_sys_mol1

# %% [markdown]
# ...and molecule 2

# %%
omm_sys_mol2 = OpenMM_system(topology_format='CHARMM', top_file=paths.mm_mol2_top, crd_format='PDB',
                        crd_file=paths.mm_mol2_crd, charmm_param_file=paths.mm_stream, pbc=True,
                        cell=[1.6, 1.6, 1.6], angles=[90, 90, 90])

# %%
omm_sys_mol2.create_system_params['nonbondedCutoff'] = 0.8 * unit.nanometer
omm_sys_mol2.create_system_params['constraints'] = app.HBonds
omm_sys_mol2.import_molecular_system()
omm_sys_mol2.set_integrator()
omm_sys_mol2.set_platform()
omm_sys_mol2.create_openmm_system()
omm_sys_mol2.set_openmm_context()
# Out:
# /home/ac127777/Documents/TheForce/OMM_interface
# /home/ac127777/Documents/TheForce/OMM_interface/top_all36_cgenff.rtf
# Number of constraints: 232
# constraints settings: HBonds
# make sure these are correct before setting context

# %%
Molsys.openmm_systems['mol2'] = omm_sys_mol2

# %% [markdown]
# ...or the molecule without solvent

# %% [raw]
# omm_sys_nosol = OpenMM_system(topology_format='CHARMM', top_file=paths.mm_nosol_top, crd_format='PDB',
#                         crd_file=paths.mm_nosol_crd, charmm_param_file=paths.mm_stream, pbc=True,
#                         cell=[1.6, 1.6, 1.6], angles=[90, 90, 90])

# %% [raw]
# omm_sys_nosol.create_system_params['nonbondedCutoff'] = 0.8 * unit.nanometer
# omm_sys_nosol.create_system_params['constraints'] = app.HBonds
# omm_sys_nosol.import_molecular_system()
# omm_sys_nosol.set_integrator()
# omm_sys_nosol.set_platform()
# omm_sys_nosol.create_openmm_system()
# omm_sys_nosol.set_openmm_context()

# %% [raw]
# Molsys.openmm_systems['nosol'] = omm_sys_nosol

# %% [markdown]
# ### ...now extract the force field...

# %%
for omm_system_name in Molsys.openmm_systems.keys():
    if Molsys.openmm_systems[omm_system_name] != None:
        Molsys.openmm_systems[omm_system_name].extract_forcefield()

# %%
for omm_system_name in Molsys.openmm_systems.keys():
    if Molsys.openmm_systems[omm_system_name] != None:
        Molsys.openmm_systems[omm_system_name].create_force_field_optimizable(opt_charges=True, opt_lj=True)

# %%
for omm_system_name in Molsys.openmm_systems.keys():
    if Molsys.openmm_systems[omm_system_name] != None:
        Molsys.get_mm_charges(omm_system_name)

# %% [markdown]
# ### ...calculate the classical forces...

# %%
for omm_system_name in Molsys.openmm_systems.keys():
    if Molsys.openmm_systems[omm_system_name] != None:
        Molsys.generate_mm_energies_forces(omm_system_name, verbose = True)
# Out:
# ########################################
# # calculated MM F&E of 50 frames
# ########################################
# ########################################
# # calculated MM F&E of 50 frames
# ########################################
# ########################################
# # calculated MM F&E of 50 frames
# ########################################

# %% [markdown]
# ### calculate MM net forces

# %%
Molsys.calculate_mm_net_forces()

# %%
mm_forces_ini = copy.deepcopy(Molsys.mm_forces)
mm_net_forces_ini = copy.deepcopy(Molsys.mm_net_forces)

# %% [markdown]
# ### reduce parameter set

# %%
Molsys.get_types_from_psf_topology_file()
# Out:
# {'nosol': [],
#  'all': array([[0, 'CG321'],
#         [1, 'OG303'],
#         [2, 'PG2'],
#         [3, 'OG2P1'],
#         [4, 'OG2P1'],
#         [5, 'OG2P1'],
#         [6, 'HGA2'],
#         [7, 'HGA2'],
#         [8, 'CG331'],
#         [9, 'HGA3'],
#         [10, 'HGA3'],
#         [11, 'HGA3'],
#         [12, 'OT'],
#         [13, 'HT'],
#         [14, 'HT'],
#         [15, 'OT'],
#         [16, 'HT'],
#         [17, 'HT'],
#         [18, 'OT'],
#         [19, 'HT'],
#         [20, 'HT'],
#         [21, 'OT'],
#         [22, 'HT'],
#         [23, 'HT'],
#         [24, 'OT'],
#         [25, 'HT'],
#         [26, 'HT'],
#         [27, 'OT'],
#         [28, 'HT'],
#         [29, 'HT'],
#         [30, 'OT'],
#         [31, 'HT'],
#         [32, 'HT'],
#         [33, 'OT'],
#         [34, 'HT'],
#         [35, 'HT'],
#         [36, 'OT'],
#         [37, 'HT'],
#         [38, 'HT'],
#         [39, 'OT'],
#         [40, 'HT'],
#         [41, 'HT'],
#         [42, 'OT'],
# ...

# %%
slice_list = {'all': [np.r_[1:6]], #ep2
              'mol1': [np.r_[1:6]],
              }

# %% [markdown]
# by defining the atoms for which the parameters are supposed to be optimized in the slice_list

# %% [raw]
# slice_list = {'all': [np.r_[1:6, 9]], #ep1mam
#               'mol1': [np.r_[1:6, 9]],
#               }

# %% [raw]
# slice_list = {'all': [np.r_[1:6, 9]], #ep1
#               'mol1': [np.r_[1:6, 9]],
#               }

# %% [raw]
# slice_list = {'all': [np.r_[0:5, 9:14]],
#               'mol1': [np.r_[0:5]],
#               'mol2': [np.r_[0:5]]} #mp2mp2

# %% [raw]
# slice_list = {'all': [np.r_[0:5]],
#               'mol1': [np.r_[0:5]]} #mp2mam

# %% [raw]
# slice_list = {'all': [np.r_[0:5]], #mp2
#               'mol1': [np.r_[0:5]],
#               }

# %% [raw]
# slice_list = {'all': [np.r_[9:14, 17]], #mp1mam
#               'mol2': [np.r_[1:6, 9]]}

# %% [raw]
# slice_list = {'all': [np.r_[1,2:6, 9:11, 12:17, 20:22]], #mp0mp0
#               'mol1': [np.r_[1,2:6, 9:11]],
#               'mol2': [np.r_[1,2:6, 9:11]],
#               }

# %% [raw]
# slice_list = {'all': [np.r_[1,2:6, 9:11]], #mp0mam
#               'mol1': [np.r_[1,2:6, 9:11]],
#               }

# %% [raw]
# slice_list = {'all': [np.r_[1,2:6, 9]], #mp1
#               'nosol': [np.r_[1,2:6, 9]]
#               }

# %% [raw]
# slice_list = {'all': [np.r_[1,2:6, 9, 11:16, 19]], #mp1mp1
#               'mol1': [np.r_[1,2:6, 9]],
#               'mol2': [np.r_[1,2:6, 9]],
#               }

# %% [markdown]
# and applying it, automatically removing duplicates

# %%
Molsys.reduce_ff_optimizable(slice_list)
# Out:
# hybrid check not performed
# performing hybrid check...
# hybrid sys found
# hybrid set to True

# %%
Molsys.reduced_indexed_ff_optimizable
# Out:
# {'all': {'CustomNonbondedForce': [array([[0.293996576986312, 0.41840000000000005, 'OG303', 1],
#           [0.38308644880034587, 2.44764, 'PG2', 2],
#           [0.30290556416771536, 0.50208, 'OG2P1', 3]], dtype=object),
#    array([[0.31600000000000006, 0.31388368000000005, 'SOD', 'OG2P1', 1]],
#          dtype=object)],
#   'NonbondedForce': [array([[1, 'OG303', -0.401],
#           [2, 'PG2', 1.1],
#           [3, 'OG2P1', -0.9]], dtype=object)]},
#  'mol1': {'NonbondedForce': [array([[1, 'OG303', -0.401, 0.29399657698631193, 0.41840000000000005],
#           [2, 'PG2', 1.1, 0.38308644880034587, 2.44764],
#           [3, 'OG2P1', -0.9, 0.30290556416771536, 0.50208]], dtype=object)]}}

# %%
Molsys.reduced_ff_optimizable_values
# Out:
# {'all': {'CustomNonbondedForce': [array([[0.293996576986312, 0.41840000000000005],
#           [0.38308644880034587, 2.44764],
#           [0.30290556416771536, 0.50208]], dtype=object),
#    array([[0.31600000000000006, 0.31388368000000005]], dtype=object)],
#   'NonbondedForce': [array([[-0.401],
#           [1.1],
#           [-0.9]], dtype=object)]},
#  'mol1': {'NonbondedForce': [array([[-0.401, 0.29399657698631193, 0.41840000000000005],
#           [1.1, 0.38308644880034587, 2.44764],
#           [-0.9, 0.30290556416771536, 0.50208]], dtype=object)]}}

# %% [markdown]
# vectorize 'em

# %%
Molsys.vectorize_reduced_parameters()

# %%
Molsys.vectorized_reduced_ff_optimizable_values
# Out:
# {'CustomNonbondedForce': [array([0.293996576986312, 0.41840000000000005, 0.38308644880034587,
#          2.44764, 0.30290556416771536, 0.50208], dtype=object),
#   array([0.31600000000000006, 0.31388368000000005], dtype=object)],
#  'NonbondedForce': [array([-0.401, 1.1, -0.9], dtype=object)]}

# %%
Molsys.merge_vectorized_parameters()

# %%
Molsys.vectorized_parameters
# Out:
# array([ 0.29399658,  0.4184    ,  0.38308645,  2.44764   ,  0.30290556,
#         0.50208   ,  0.316     ,  0.31388368, -0.401     ,  1.1       ,
#        -0.9       ])

# %% [markdown]
# scale 'em

# %%
Molsys.scale_initial_parameters()

# %%
Molsys.scaled_parameters
# Out:
# array([-0.05152249, -0.00829654, -0.02449725,  6.1566378 , -0.04971239,
#         0.04253306, -0.04669195, -0.04720914,  0.41845158,  0.91487634,
#         1.50023674])

# %%
Molsys.scaling_factors # have to be const
# Out:
# array([-0.1752486 , -0.0198292 , -0.06394705,  2.51533632, -0.16411845,
#         0.08471371, -0.14775934, -0.15040329, -1.04352016,  0.83170577,
#        -1.66692971])

# %% [markdown]
# add weights

# %% [raw]
# # throw out faulty frame22 from mp0mam
# weights = np.ones((Molsys.n_conformations))
# weights[22] = 0
# weights = weights / (np.sum(weights))
# Molsys.weights = weights

# %% [raw]
# # throw out faulty frames 0,3 from mp2mp2 and many more from mp2mam
# weights = np.ones((Molsys.n_conformations))
# weights[np.r_[6,7,9,11,12,15:19,21,22,25:28,31,37,41,43,45,47:50]] = 0
# weights = weights / (np.sum(weights))
# Molsys.weights = weights

# %%
# throw out faulty frame16 from ep2
weights = np.ones((Molsys.n_conformations))
weights[16] = 0
weights = weights / (np.sum(weights))
Molsys.weights = weights

# %%
weights
# Out:
# array([0.02083333, 0.02083333, 0.02083333, 0.02083333, 0.02083333,
#        0.02083333, 0.02083333, 0.02083333, 0.02083333, 0.02083333,
#        0.02083333, 0.02083333, 0.02083333, 0.02083333, 0.02083333,
#        0.02083333, 0.        , 0.02083333, 0.02083333, 0.02083333,
#        0.02083333, 0.02083333, 0.02083333, 0.02083333, 0.02083333,
#        0.02083333, 0.02083333, 0.02083333, 0.02083333, 0.02083333,
#        0.02083333, 0.02083333, 0.02083333, 0.02083333, 0.02083333,
#        0.02083333, 0.02083333, 0.02083333, 0.02083333, 0.02083333,
#        0.02083333, 0.02083333, 0.02083333, 0.02083333, 0.02083333,
#        0.02083333, 0.02083333, 0.02083333, 0.02083333, 0.02083333])

# %% [markdown]
# ### optimize

# %% [markdown]
# initialize Optimizer and change settings

# %% [raw]
# ini_simp = ([-0.6960695582156922, 0.2988648732412171,
#            0.8823251680901996,
#           1.6080126672034531, -0.41332654897298376,
#            0.7206696799969193,
#           -0.577191134905967, 0.4153039068047036,
#            0.022358228759260943,
#           -0.9264757700329689, 0.2850915692338954,
#            1.911294300070185]) * Molsys.scaling_factors

# %% [raw]
# opt_dict = {'initial_simplex': ini_simp, 'adaptive': True}

# %%
opt_dict = {'adaptive': True} # Nelder-mead only

# %%
Opti = Optimizer('scipy_local', {'method': 'Nelder-Mead', 'options': opt_dict})
Opti.enforce_constraints = True

# %% [raw]
# Opti = Optimizer('scipy_local', {'method': 'Powell'})

# %%
Opti.max_iterations = 10000

# %% [raw]
# Opti2 = Optimizer('cma', {'method': 'EvolutionStrategy'})

# %% [raw]
# outputpath = '/home/ac127777/Documents/TheForceOutput/mp0mam'

# %% [raw]
# Opti3 = Optimizer('bayesian', {'options':{'bo_outfile': outputpath}})

# %%
Opti.tolerance = 1e-5

# %% [raw]
# Opti.tolerance = 1e-3

# %% [raw]
# Opti2.opt_settings

# %% [raw]
# Opti.opt_method

# %% [raw]
# Opti.tolerance = 1e-04
# Opti.tolerance

# %%
Opti.opt_settings
# Out:
# {'method': 'Nelder-Mead', 'options': {'adaptive': True}}

# %% [markdown]
# initialize Parametrization module

# %%
Para = Parametrization(Molsys, 'force_c', Opti, 'auto')

# %% [raw]
# Para2 = Parametrization(Molsys, 'force', Opti2)

# %% [markdown]
# Run the parametrization loop

# %%
Para.parametrize(Molsys.scaled_parameters)
# Out:
# ###################################################################################
# #                         STARTING SCIPY_LOCAL OPTIMIZER
# ###################################################################################
# ###################################################################################
# #                         SCIPY_LOCAL OPTIMIZER FINISHED
# ###################################################################################
# optimized parameters:
# [-0.05667986 -0.00840798 -0.01379741  6.18760802 -0.05311327  0.04423202
#  -0.04961809 -0.05185146  0.4448418   0.92703201  1.5174607 ]
# objective function value:
# 0.01356179044516525

# %%
Opti.opt_settings
# Out:
# {'method': 'Nelder-Mead',
#  'options': {'maxiter': 10000},
#  'tol': 1e-05,
#  'bounds': array([[-1.75248605e-01, -5.25745814e-03],
#         [-3.96584035e-01, -3.96584035e-05],
#         [-6.39470476e-02, -1.91841143e-03],
#         [ 5.03067264e-03,  5.03067264e+01],
#         [-1.64118449e-01, -4.92355347e-03],
#         [ 1.69427413e-04,  1.69427413e+00],
#         [-1.47759338e-01, -2.95518676e-02],
#         [-2.33125106e+00, -9.02419765e-03],
#         [-0.00000000e+00,  2.08704031e+00],
#         [ 0.00000000e+00,  4.99023460e+00],
#         [-0.00000000e+00,  3.33385941e+00]])}

# %% [raw]
# Para2.parametrize(Molsys.scaled_parameters)

# %% [markdown]
# check output

# %%
Para.parameters # params out
# Out:
# array([-0.05667986, -0.00840798, -0.01379741,  6.18760802, -0.05311327,
#         0.04423202, -0.04961809, -0.05185146,  0.4448418 ,  0.92703201,
#         1.5174607 ])

# %% [raw]
# Para2.parameters

# %%
Para.iterations
# Out:
# 25743

# %% [raw]
# Para2.iterations

# %%
Molsys.reduced_indexed_ff_optimizable
# Out:
# {'all': {'CustomNonbondedForce': [array([[0.3234254759161587, 0.4240201476359742, 'OG303', 1],
#           [0.2157630343060931, 2.459952558318135, 'PG2', 2],
#           [0.32362767388845814, 0.5221353272207353, 'OG2P1', 3]],
#          dtype=object),
#    array([[0.33580341155994586, 0.3447495018373475, 'SOD', 'OG2P1', 1]],
#          dtype=object)],
#   'NonbondedForce': [array([[1, 'OG303', -0.4262896137364945],
#           [2, 'PG2', 1.1146153461471149],
#           [3, 'OG2P1', -0.9103327452445908]], dtype=object)]},
#  'mol1': {'NonbondedForce': [array([[1, 'OG303', -0.4262896137364945, 0.3234254759161587,
#            0.4240201476359742],
#           [2, 'PG2', 1.1146153461471149, 0.2157630343060931,
#            2.459952558318135],
#           [3, 'OG2P1', -0.9103327452445908, 0.32362767388845814,
#            0.5221353272207353]], dtype=object)]}}

# %%
Molsys.reduced_ff_optimizable_values
# Out:
# {'all': {'CustomNonbondedForce': [array([[0.3234254759161587, 0.4240201476359742],
#           [0.2157630343060931, 2.459952558318135],
#           [0.32362767388845814, 0.5221353272207353]], dtype=object),
#    array([[0.33580341155994586, 0.3447495018373475]], dtype=object)],
#   'NonbondedForce': [array([[-0.4262896137364945],
#           [1.1146153461471149],
#           [-0.9103327452445908]], dtype=object)]},
#  'mol1': {'NonbondedForce': [array([[-0.4262896137364945, 0.3234254759161587, 0.4240201476359742],
#           [1.1146153461471149, 0.2157630343060931, 2.459952558318135],
#           [-0.9103327452445908, 0.32362767388845814, 0.5221353272207353]],
#          dtype=object)]}}

# %% [markdown]
# check optimizer

# %%
Para.optimizer.scipy_optimization
# Out:
#  final_simplex: (array([[-0.05667986, -0.00840798, -0.01379741,  6.18760802, -0.05311327,
#          0.04423202, -0.04961809, -0.05185146,  0.4448418 ,  0.92703201,
#          1.5174607 ],
#        [-0.05667986, -0.00840798, -0.01379741,  6.18760802, -0.05311327,
#          0.04423202, -0.04961809, -0.05185146,  0.4448418 ,  0.92703201,
#          1.5174607 ],
#        [-0.05667986, -0.00840798, -0.01379741,  6.18760802, -0.05311327,
#          0.04423202, -0.04961809, -0.05185146,  0.4448418 ,  0.92703201,
#          1.5174607 ],
#        [-0.05667986, -0.00840798, -0.01379741,  6.18760802, -0.05311327,
#          0.04423202, -0.04961809, -0.05185146,  0.4448418 ,  0.92703201,
#          1.5174607 ],
#        [-0.05667986, -0.00840798, -0.01379741,  6.18760802, -0.05311327,
#          0.04423202, -0.04961809, -0.05185146,  0.4448418 ,  0.92703201,
#          1.5174607 ],
#        [-0.05667986, -0.00840798, -0.01379741,  6.18760802, -0.05311327,
# ...

# %% [raw]
# Para.optimizer.bayesian_optimization.bounds

# %%
Molsys.openmm_systems['all'].nbfix
# Out:
# array([[0.3467687252569493, 0.08203582771612483, 'OG2P1', 'SOD'],
#        [0.3467687252569493, 0.08203582771612483, 'SOD', 'OG2P1']],
#       dtype=object)
